# %%
keys=["name1","name2","name3","name4",]
values=["sara","ali","mohamed","ahmed"]
def create_dict(l1, l2):
    my_dict = {}
    if len(l1)==len(l2):
        for i in range(len(l1)):
            my_dict[l1[i]] = len(l2[i])
            print(my_dict)
        if type(l1) == type(l2):
            print("the two lists are equal")
        else:
            print("the two lists are not equal")    
    else:
        print("the two numbers not equal")
    return my_dict
print(create_dict(keys, values))
# Out:
# {'name1': 4}
# {'name1': 4, 'name2': 3}
# {'name1': 4, 'name2': 3, 'name3': 7}
# {'name1': 4, 'name2': 3, 'name3': 7, 'name4': 5}
# the two lists are equal
# {'name1': 4, 'name2': 3, 'name3': 7, 'name4': 5}

# %%
d1 = {"a":100, "b":200}
d2 = {"a":300, "y":200}
def merge_ave(d1,d2):
    merg_dict = {}
    

    for keys , values in d1.items():
        merg_dict[keys]=[values]
        print(merg_dict)

    for keys , values in d2.items():
        if keys in merg_dict:
            merg_dict[keys].append(values)
            average = sum(merg_dict[keys])/len(merg_dict[keys])
        else:
            merg_dict[keys]=[values]

    print(f"merg_dict: {merg_dict}, average: {average}")

# %%
merge_ave(d1,d2)
# Out:
# {'a': [100]}
# {'a': [100], 'b': [200]}
# merg_dict: {'a': [100, 300], 'b': [200], 'y': [200]}, average: 200.0
